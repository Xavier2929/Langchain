# %%
import config
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableParallel

# %%
chat_template_books = ChatPromptTemplate.from_template(
    '''
        Suggest three of the best intermediate-level {programming language} books.
        Answer only by listing the books.
    '''
)

chat_template_projects = ChatPromptTemplate.from_template(
    '''
    Suggest three interesting {programming language} projects suitable for intermediate-level programmers.
    Answer only by listing the projects.
    '''
)

chat_template_time = ChatPromptTemplate.from_template(
    '''
I'm an intermediate level programmer.

Consider the following literature:
{books}

ALso consider the following projects:
{projects}

Roughly, how much time would it take me to complete the literature and the projects?
    '''
)

# %%
chat = ChatOpenAI(
    api_key = config.api_key,
    model='gpt-4',
    temperature = 0,
    max_tokens = 500 ,
    model_kwargs = {'seed':365},
    
)
# Out:
# c:\Users\user\miniconda3\envs\langchain_env\lib\site-packages\IPython\core\interactiveshell.py:3519: UserWarning: Parameters {'seed'} should be specified explicitly. Instead they were passed in as part of `model_kwargs` parameter.
#   if await self.run_code(code, result, async_=asy):

# %%
string_parser = StrOutputParser()

chain_books = chat_template_books | chat | string_parser
chain_projects = chat_template_projects | chat | string_parser

# %%
chain_parallel = RunnableParallel(
    {'books':chain_books,
     'projects':chain_projects
     }
    )

# %%
chain_parallel.invoke({'programming language':'C#'})
# Out:
# {'books': '1. "C# in Depth" by Jon Skeet\n2. "Pro C# 5.0 and the .NET 4.5 Framework" by Andrew Troelsen\n3. "C# 7.0 in a Nutshell: The Definitive Reference" by Joseph Albahari and Ben Albahari',
#  'projects': '1. A Personal Finance Management Application: This application can help users track their income, expenses, savings, and investments. It can also provide features like budgeting, reminders for bill payments, and financial reports.\n\n2. A Weather Forecast Application: This application can fetch weather data from an API and display current weather conditions, forecasts, and weather maps. It can also include features like weather alerts and sharing weather updates on social media.\n\n3. An E-commerce Website: This website can allow users to browse products, add them to a shopping cart, and make purchases. It can also include features like user registration, product reviews, and order tracking.'}

# %%
chain_time = (
    RunnableParallel({'books':chain_books,
                      'projects':chain_projects}) 
                      | chat_template_time
                      | chat
                      | string_parser
)

# %%
print(chain_time.invoke({'programming language':'c#'}))
# Out:
# The time it would take to complete the literature and the projects can vary greatly depending on several factors such as your current skill level, the complexity of the projects, and the amount of time you can dedicate to studying and coding each day.
#
# However, here's a rough estimate:
#
# 1. "C# in Depth" by Jon Skeet: This book is around 600 pages. If you read and practice for about 2 hours a day, it might take you around 1-2 months to complete.
#
# 2. "Pro C# 7: With .NET and .NET Core" by Andrew Troelsen: This book is more than 1300 pages. Following the same reading and practicing schedule, it might take you around 3-4 months to complete.
#
# 3. "C# 7.0 in a Nutshell: The Definitive Reference" by Joseph Albahari and Ben Albahari: This book is around 1100 pages. It might take you around 2-3 months to complete.
#
# As for the projects:
#
# 1. A Personal Finance Management System: Depending on the complexity and the features you want to include, this could take anywhere from 1-3 months.
#
# 2. A Social Media Aggregator: This could be a complex project depending on the number of social media platforms you want to include and the features you want to implement. It could take anywhere from 2-4 months.
#
# 3. An E-commerce Website: This is likely the most complex project of the three and could take anywhere from 3-6 months.
#
# Please note that these are very rough estimates and the actual time could be less or more depending on various factors. It's also important to note that learning and building projects is not a race. It's more important to understand the concepts and build the projects well rather than rushing through them.

# %%
chain_parallel.get_graph().print_ascii()
# Out:
#             +-------------------------------+
#             | Parallel<books,projects>Input |
#             +-------------------------------+
#                    ***               ***
#                 ***                     ***
#               **                           **
# +--------------------+              +--------------------+
# | ChatPromptTemplate |              | ChatPromptTemplate |
# +--------------------+              +--------------------+
#            *                                   *
#            *                                   *
#            *                                   *
#     +------------+                      +------------+
#     | ChatOpenAI |                      | ChatOpenAI |
#     +------------+                      +------------+
#            *                                   *
#            *                                   *
#            *                                   *
#   +-----------------+                 +-----------------+
#   | StrOutputParser |                 | StrOutputParser |
#   +-----------------+                 +-----------------+
#                    ***               ***
#                       ***         ***
#                          **     **
#             +--------------------------------+
#             | Parallel<books,projects>Output |
#             +--------------------------------+
