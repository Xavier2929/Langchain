# %% [markdown]
# theirs more into the parameters we can use for consuming the openai API,
# we can limit the max_tokens (usually this limits the characters of the response) and adjust temperature (the exactness , if that's even a word lol ) of the response.

# %%
import config
import openai

# %%
client = openai.OpenAI(api_key = config.api_key)

# %%
completions = client.chat.completions.create(
    model = 'gpt-4',
    messages=[
        {
            'role':'system',
            'content': ''' you're a chess coach from the russin school of chess,
                    you'll be answering chess related questions, and if someone asks
                    something differente you'll respond on a typical russian manner.
                    usually you'll get asked, pawn structure related questions, pinpointing
                    stragy and positional concepts. '''
        },
        {

            'role' :'user',
            'content': ''' could you give me a classifcal isolani pawn structure 
                        chess game, and pinpoint the important parts? '''
        }
    ],
    max_tokens = 300,
    temperature = 0

)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 completions = client.chat.completions.create(
#       2     model = 'gpt-5-nano', #cheap guy, I know
#       3     messages=[
#       4         {
#       5             'role':'system',
#       6             'content': ''' you're a chess coach from the russin school of chess,
#       7                     you'll be answering chess related questions, and if someone asks
#       8                     something differente you'll respond on a typical russian manner.
#       9                     usually you'll get asked, pawn structure related questions, pinpointing
#      10                     stragy and positional concepts. '''
#      11         },
#      12         {
#      13
#      14             'role' :'user',
#      15             'content': ''' could you give me a classifcal isolani pawn structure
#      16                         chess game, and pinpoint the important parts? '''
#      17         }
#      18     ],
#      19     max_output_tokens  =512 , # on other models it may be max_tokens,
#      20     reasoning={
#      21         'effort':'low'
#      22     }
#      23
#      24 )
#
# File c:\Users\user\miniconda3\envs\langchain_env\lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# TypeError: Completions.create() got an unexpected keyword argument 'max_output_tokens'

# %%
print(completions)
# Out:
# ChatCompletion(id='chatcmpl-DCf41iQ9ATBa3alOfdtSihg7H4DRd', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1771910157, model='gpt-5-nano-2025-08-07', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=512, prompt_tokens=93, total_tokens=605, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=512, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
